# %%
# Out:
#       ┌───┐┌─┐                                             ┌─┐               »
#  q_0: ┤ H ├┤M├─────────────────────────────────────────────┤M├───────────────»
#       ├───┤└╥┘┌─┐                                          └╥┘┌─┐            »
#  q_1: ┤ H ├─╫─┤M├───────────────────────────────────────────╫─┤M├────────────»
#       ├───┤ ║ └╥┘┌─┐                                        ║ └╥┘┌─┐         »
#  q_2: ┤ H ├─╫──╫─┤M├────────────────────────────────────────╫──╫─┤M├─────────»
#       ├───┤ ║  ║ └╥┘┌─┐                                     ║  ║ └╥┘┌─┐      »
#  q_3: ┤ H ├─╫──╫──╫─┤M├─────────────────────────────────────╫──╫──╫─┤M├──────»
#       ├───┤ ║  ║  ║ └╥┘┌─┐                                  ║  ║  ║ └╥┘┌─┐   »
#  q_4: ┤ H ├─╫──╫──╫──╫─┤M├──────────────────────────────────╫──╫──╫──╫─┤M├───»
#       ├───┤ ║  ║  ║  ║ └╥┘┌─┐                               ║  ║  ║  ║ └╥┘┌─┐»
#  q_5: ┤ H ├─╫──╫──╫──╫──╫─┤M├───────────────────────────────╫──╫──╫──╫──╫─┤M├»
# ...

# %%
# Out:
# Random number (decimal): 38936

# %%
# Out:
# Random number (binary): 1001100000011000

# %%
! pip install pylatexenc
# Out:
# ...
#      ---------------------------------------- 0.0/162.6 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.6 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.6 kB ? eta -:--:--
#      ---- --------------------------------- 20.5/162.6 kB 93.9 kB/s eta 0:00:02
#      --------- --------------------------- 41.0/162.6 kB 178.6 kB/s eta 0:00:01
#      ------------- ----------------------- 61.4/162.6 kB 218.8 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/162.6 kB 473.7 kB/s eta 0:00:01
#      ------------------------------------ 162.6/162.6 kB 488.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136848 sha256=2012cff545fab931eb406dd7266c59ba436a4d9abd293400e18e4e882818b85c
# ...
